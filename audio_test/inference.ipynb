# %%
import torch
import torchaudio
from urbansounddataset import UrbanSoundDataset
from cnn import CNNNetwork
from train import AUDIO_DIR,ANNOTATIONS_FILE,SAMPLE_RATE,NUM_SAMPLES

# %%
class_mapping = [
    "air_conditioner",
    "car_horn",
    "veledler",
    "dog_bark",
    "drilling",
    "engine_idling",
    "gun_shot",
    "jackhammer",
    "siren",
    "street_music"
]

# %%
def predict(model, input, target, class_mapping):
    model.eval()
    with torch.no_grad():
        predictions = model(input)
        # Tensor (noOfSamples,noOfClasses)
        predicted_index = predictions[0].argmax()
        predicted = class_mapping[predicted_index]
        expected = class_mapping[target]
    return predicted,expected

# %%
## load the model
cnn = CNNNetwork()
state_dict = torch.load("cnn.pth")
cnn.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
##load dataset
mel_spectogram = torchaudio.transforms.MelSpectrogram(
    sample_rate=SAMPLE_RATE,
    n_fft=1024,
    hop_length=512,
    n_mels=64
)

usd = UrbanSoundDataset (ANNOTATIONS_FILE, AUDIO_DIR, mel_spectogram,
                        SAMPLE_RATE,NUM_SAMPLES,"cpu")

# %%
##get a se sample from the urbansounddataset for inference
correct =[]
false =[]

for i in range(len(usd)):    
    input, target = usd[i][0],usd[i][1] ## [batch_size, num channels, freq, time]
    input.unsqueeze_(0)
    predicted, expected = predict(cnn,input,target,class_mapping)
    print(f"Predicted: {predicted} , Expected: {expected}")
    if predicted == expected:
        correct.append(predicted)
    else:
        false.append(predicted)
# Out:
# Predicted: veledler , Expected: dog_bark
# Predicted: siren , Expected: veledler
# Predicted: siren , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: siren , Expected: veledler
# Predicted: air_conditioner , Expected: veledler
# Predicted: siren , Expected: veledler
# Predicted: air_conditioner , Expected: veledler
# Predicted: air_conditioner , Expected: veledler
# Predicted: drilling , Expected: car_horn
# Predicted: drilling , Expected: car_horn
# Predicted: drilling , Expected: car_horn
# Predicted: drilling , Expected: car_horn
# Predicted: veledler , Expected: car_horn
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: veledler , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: air_conditioner , Expected: air_conditioner
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: drilling , Expected: air_conditioner
# Predicted: air_conditioner , Expected: street_music
# Predicted: air_conditioner , Expected: street_music
# Predicted: air_conditioner , Expected: street_music
# Predicted: air_conditioner , Expected: street_music
# Predicted: air_conditioner , Expected: street_music
# Predicted: air_conditioner , Expected: street_music
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: air_conditioner , Expected: gun_shot
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: veledler , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: veledler , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: drilling , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: drilling , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: drilling , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: veledler , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: drilling , Expected: jackhammer
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: air_conditioner , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: drilling , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: veledler , Expected: engine_idling
# Predicted: drilling , Expected: engine_idling
# Predicted: veledler , Expected: engine_idling
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: drilling , Expected: gun_shot
# Predicted: drilling , Expected: car_horn
# Predicted: drilling , Expected: car_horn
# Predicted: drilling , Expected: dog_bark
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: veledler , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: air_conditioner , Expected: siren
# Predicted: veledler , Expected: street_music
# Predicted: siren , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: air_conditioner , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: siren , Expected: street_music
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: air_conditioner , Expected: drilling
# Predicted: drilling , Expected: drilling
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: drilling , Expected: street_music
# Predicted: drilling , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: drilling , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: air_conditioner , Expected: street_music
# Predicted: air_conditioner , Expected: street_music
# Predicted: air_conditioner , Expected: street_music
# Predicted: air_conditioner , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: drilling , Expected: street_music
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: air_conditioner , Expected: veledler
# Predicted: air_conditioner , Expected: veledler
# Predicted: drilling , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: drilling , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: drilling , Expected: street_music
# Predicted: drilling , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: veledler
# Predicted: air_conditioner , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: veledler , Expected: veledler
# Predicted: air_conditioner , Expected: veledler
# Predicted: drilling , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: drilling , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: air_conditioner , Expected: jackhammer
# Predicted: drilling , Expected: gun_shot
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: air_conditioner , Expected: dog_bark
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: street_music
# Predicted: veledler , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: air_conditioner , Expected: dog_bark
# Predicted: veledler , Expected: dog_bark
# Predicted: air_conditioner , Expected: gun_shot
# Predicted: veledler , Expected: engine_idling
# Predicted: veledler , Expected: engine_idling
# Predicted: veledler , Expected: engine_idling
# Predicted: air_conditioner , Expected: engine_idling
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 5>()
#       3 false =[]
#       5 for i in range(len(usd)):
# ----> 6     input, target = usd[i][0],usd[i][1] ## [batch_size, num channels, freq, time]
#       7     input.unsqueeze_(0)
#       8     predicted, expected = predict(cnn,input,target,class_mapping)
#
# File ~\Desktop\makamFinder\pytorch_test\audio_test\urbansounddataset.py:33, in UrbanSoundDataset.__getitem__(self, index)
#      31 signal, sr = torchaudio.load(audio_sample_path)
#      32 signal = signal.to(self.device)
# ---> 33 signal = self._resample_if_necessary(signal,sr)
#      34 signal = self._mix_down_if_necessary(signal)
#      35 signal = self._right_pad_if_necessary(signal) ## if the number of samples is less then we want
#
# File ~\Desktop\makamFinder\pytorch_test\audio_test\urbansounddataset.py:54, in UrbanSoundDataset._resample_if_necessary(self, signal, sr)
#      52 def _resample_if_necessary(self, signal, sr):
#      53     if sr != self.target_sample_rate:
# ---> 54         resampler = torchaudio.transforms.Resample(sr, self.target_sample_rate)
#      55         signal = resampler(signal)
#      56     return signal
#
# File ~\anaconda3\lib\site-packages\torchaudio\transforms\_transforms.py:937, in Resample.__init__(self, orig_freq, new_freq, resampling_method, lowpass_filter_width, rolloff, beta, dtype)
#     934 self.beta = beta
#     936 if self.orig_freq != self.new_freq:
# --> 937     kernel, self.width = _get_sinc_resample_kernel(
#     938         self.orig_freq,
#     939         self.new_freq,
#     940         self.gcd,
#     941         self.lowpass_filter_width,
#     942         self.rolloff,
#     943         self.resampling_method,
#     944         beta,
#     945         dtype=dtype,
#     946     )
#     947     self.register_buffer("kernel", kernel)
#
# File ~\anaconda3\lib\site-packages\torchaudio\functional\functional.py:1457, in _get_sinc_resample_kernel(orig_freq, new_freq, gcd, lowpass_filter_width, rolloff, resampling_method, beta, device, dtype)
#    1454 # we do not use built in torch windows here as we need to evaluate the window
#    1455 # at specific positions, not over a regular grid.
#    1456 if resampling_method == "sinc_interpolation":
# -> 1457     window = torch.cos(t * math.pi / lowpass_filter_width / 2) ** 2
#    1458 else:
#    1459     # kaiser_window
#    1460     if beta is None:
#
# KeyboardInterrupt:

# %%
print("number of correct: " + str(len(correct)))
print("number of false: "+str(len(false)) )
# Out:
# number of correct: 1918
# number of false: 6814
